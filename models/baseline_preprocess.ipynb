# %%
import pandas as pd
import numpy as np

df = pd.read_csv('..\processed\stock_price_monthly_2003_2024_processed.csv')
df["date"] = pd.to_datetime(df["date"]).dt.to_period('M')
df.head(10)
# Out:
# C:\Users\vietx\AppData\Local\Temp\ipykernel_34116\856549930.py:5: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["date"] = pd.to_datetime(df["date"]).dt.to_period('M')
#       date    NCUSIP TICKER           COMNAM      PRC        RET  SHROUT  \
# 0  2002-01  29274A10   EWST  ENERGY WEST INC  11.3000  -0.013100  2566.0
# 1  2002-02  29274A10   EWST  ENERGY WEST INC  10.7000  -0.053097  2569.0
# 2  2002-03  29274A10   EWST  ENERGY WEST INC  10.4000  -0.015888  2571.0
# 3  2002-04  29274A10   EWST  ENERGY WEST INC   9.9500  -0.043269  2571.0
# 4  2002-05  29274A10   EWST  ENERGY WEST INC  10.0975   0.014824  2571.0
# 5  2002-06  29274A10   EWST  ENERGY WEST INC   9.7200  -0.024016  2574.0
# 6  2002-07  29274A10   EWST  ENERGY WEST INC   8.7500  -0.099794  2574.0
# 7  2002-08  29274A10   EWST  ENERGY WEST INC   8.9000   0.017143  2574.0
# 8  2002-09  29274A10   EWST  ENERGY WEST INC   8.7500  -0.001685  2576.0
# 9  2002-10  29274A10   EWST  ENERGY WEST INC   8.5800  -0.019429  2586.0
#
#      sprtrn  NasdaqDummy
# 0 -0.015574            1
# 1 -0.020766            1
# 2  0.036739            1
# 3 -0.061418            1
# 4 -0.009081            1
# 5 -0.072465            1
# 6 -0.078995            1
# 7  0.004881            1
# 8 -0.110013            1
# 9  0.086436            1

# %%
 # Sort data by NCUSIP (Stock ID) and date
df = df.sort_values(by=["NCUSIP", "TICKER", "date"])

df["RET"] = pd.to_numeric(df["RET"], errors="coerce")

# Compute past 12-month return (momentum measure)
df["past_return"] = (
    df.groupby("NCUSIP")["RET"]
    .rolling(window=12, min_periods=12)
    .apply(lambda x: np.prod(1 + x) - 1, raw=True)
    .reset_index(level=0, drop=True)
)

# Compute past 12-month return while skipping the most recent month
df["past_return_skip"] = (
    df.groupby("NCUSIP")["RET"]
    .rolling(window=12, min_periods=12)
    .apply(lambda x: np.prod(1 + x[:-1]) - 1, raw=True)
    .reset_index(level=0, drop=True)
)

# Compute past 12-month variance
df["past_variance"] = (
    df.groupby("NCUSIP")["RET"]
    .rolling(window=12, min_periods=12)
    .var()
    .reset_index(level=0, drop=True)
)

# Rk is the rate of return of a firm lagged k years for k 5 0,1,2,3,4
df["R1"] = df.groupby("NCUSIP")["RET"].shift(12)
df["R2"] = df.groupby("NCUSIP")["RET"].shift(24)
df["R3"] = df.groupby("NCUSIP")["RET"].shift(36)
df["R4"] = df.groupby("NCUSIP")["RET"].shift(48)


df
# Out:
#            date    NCUSIP TICKER                COMNAM      PRC       RET  \
# 141855  2014-10  00030710    AAC    A A C HOLDINGS INC  21.7800       NaN
# 141856  2014-11  00030710    AAC    A A C HOLDINGS INC  28.8600  0.325069
# 141857  2014-12  00030710    AAC    A A C HOLDINGS INC  30.9200  0.071379
# 141858  2015-01  00030710    AAC    A A C HOLDINGS INC  25.5200 -0.174644
# 141859  2015-02  00030710    AAC    A A C HOLDINGS INC  35.9900  0.410266
# ...         ...       ...    ...                   ...      ...       ...
# 94083   2017-09  U7260311   PLPM    PLANET PAYMENT INC   4.2900  0.083333
# 94084   2017-10  U7260311   PLPM    PLANET PAYMENT INC   4.4700  0.041958
# 94085   2017-11  U7260311   PLPM    PLANET PAYMENT INC   4.5000  0.006711
# 312944  2024-02  U9154A20   UMAC  UNUSUAL MACHINES INC   2.8400       NaN
# 312945  2024-03  U9154A20   UMAC  UNUSUAL MACHINES INC   1.7499 -0.383838
#
#          SHROUT    sprtrn  NasdaqDummy  past_return  past_return_skip  \
# 141855  20673.0  0.023201            0          NaN               NaN
# 141856  21081.0  0.024534            0          NaN               NaN
# 141857  21081.0 -0.004189            0          NaN               NaN
# 141858  21081.0 -0.031041            0          NaN               NaN
# 141859  21081.0  0.054893            0          NaN               NaN
# ...         ...       ...          ...          ...               ...
# 94083   49971.0  0.019303            1     0.156333          0.067385
# 94084   50012.0  0.022188            1     0.280801          0.229225
# 94085   50012.0  0.028083            1     0.119402          0.111939
# 312944   8717.0  0.051721            0          NaN               NaN
# 312945   9083.0  0.031019            0          NaN               NaN
#
#         past_variance        R1        R2        R3        R4
# 141855            NaN       NaN       NaN       NaN       NaN
# 141856            NaN       NaN       NaN       NaN       NaN
# 141857            NaN       NaN       NaN       NaN       NaN
# 141858            NaN       NaN       NaN       NaN       NaN
# 141859            NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...
# 94083        0.010623  0.033426 -0.043919 -0.186722  0.040984
# 94084        0.010074 -0.059299  0.060071 -0.137755  0.062992
# 94085        0.008491  0.151862 -0.050000 -0.026509 -0.129630
# 312944            NaN       NaN       NaN       NaN       NaN
# 312945            NaN       NaN       NaN       NaN       NaN
#
# [1144940 rows x 16 columns]

# %%
df[df["NCUSIP"] == "U7260311"].sort_values(by="date")
# Out:
#           date    NCUSIP TICKER              COMNAM     PRC       RET  \
# 94026  2012-12  U7260311   PLPM  PLANET PAYMENT INC  3.4800       NaN
# 94027  2013-01  U7260311   PLPM  PLANET PAYMENT INC  2.8500 -0.181035
# 94028  2013-02  U7260311   PLPM  PLANET PAYMENT INC  3.0100  0.056140
# 94029  2013-03  U7260311   PLPM  PLANET PAYMENT INC  2.9400 -0.023256
# 94030  2013-04  U7260311   PLPM  PLANET PAYMENT INC  3.1700  0.078231
# 94031  2013-05  U7260311   PLPM  PLANET PAYMENT INC  2.9800 -0.059937
# 94032  2013-06  U7260311   PLPM  PLANET PAYMENT INC  2.7600 -0.073826
# 94033  2013-07  U7260311   PLPM  PLANET PAYMENT INC  3.0100  0.090580
# 94048  55809.0  0.023201            1    -0.374074         -0.274074
# 94049  55809.0  0.024534            1    -0.299915         -0.280851
# 94050  55178.0 -0.004189            1    -0.251799         -0.408201
# 94051  55178.0 -0.031041            1    -0.541077         -0.410765
# 94052  55216.0  0.054893            1    -0.510264         -0.524927
# 94053  55016.0 -0.017396            1    -0.306569         -0.390511
# 94054  54259.0  0.008521            1    -0.258555         -0.277567
# 94055  54259.0  0.010491            1    -0.195035         -0.308510
# 94056  53780.0 -0.021012            1    -0.147887         -0.200703
# 94057  52549.0  0.019742            1     0.085107          0.029788
# 94058  52549.0 -0.062581            1     0.228216          0.058092
# 94059  53696.0 -0.026443            1     0.443877          0.510204
# 94060  53668.0  0.082983            1     0.775148          0.674556
# 94061  53668.0  0.000505            1     0.732313          0.823487
# 94062  52586.0 -0.017530            1     0.466346          0.370193
# 94063  52586.0 -0.050735            1     0.783951          0.882716
# 94064  51822.0 -0.004128            1     0.586827          0.730539
# 94065  51634.0  0.065991            1     0.857894          0.394737
# 94066  49988.0  0.002699            1     1.056408          0.810255
# 94067  49988.0  0.015329            1     0.898676          0.766517
# 94068  50330.0  0.000906            1     0.855369          0.780990
# 94069  50376.0  0.035610            1     0.839212          0.760782
# 94070  50376.0 -0.001219            1     0.212835          0.584457
# 94071  48855.0 -0.001234            1     0.310951          0.268549
# 94072  48902.0 -0.019426            1     0.163331          0.236664
# 94073  48902.0  0.034174            1     0.410523          0.224559
# 94074  49291.0  0.018201            1     0.337701          0.318030
# 94075  49291.0  0.017884            1     0.460204          0.411761
# 94076  49557.0  0.037198            1     0.543392          0.592449
# 94077  49697.0 -0.000389            1     0.127476          0.158637
# 94078  49755.0  0.009091            1     0.039898         -0.007483
# 94079  49755.0  0.011576            1    -0.199538         -0.032484
# 94080  49858.0  0.004814            1    -0.265035         -0.231627
# 94081  49888.0  0.019349            1    -0.309169         -0.296376
# 94082  49888.0  0.000546            1     0.103063         -0.097494
# 94083  49971.0  0.019303            1     0.156333          0.067385
# 94084  50012.0  0.022188            1     0.280801          0.229225
# 94085  50012.0  0.028083            1     0.119402          0.111939
#
#        past_variance        R1        R2        R3        R4
# 94026            NaN       NaN       NaN       NaN       NaN
# 94027            NaN       NaN       NaN       NaN       NaN
# 94028            NaN       NaN       NaN       NaN       NaN
# 94029            NaN       NaN       NaN       NaN       NaN
# 94030            NaN       NaN       NaN       NaN       NaN
# 94031            NaN       NaN       NaN       NaN       NaN
# 94032            NaN       NaN       NaN       NaN       NaN
# 94033            NaN       NaN       NaN       NaN       NaN
# 94034            NaN       NaN       NaN       NaN       NaN
# 94035            NaN       NaN       NaN       NaN       NaN
# 94036            NaN       NaN       NaN       NaN       NaN
# 94037            NaN       NaN       NaN       NaN       NaN
# 94038       0.013625       NaN       NaN       NaN       NaN
# 94039       0.016714 -0.181035       NaN       NaN       NaN
# 94040       0.016888  0.056140       NaN       NaN       NaN
# 94041       0.020687 -0.023256       NaN       NaN       NaN
# 94042       0.020247  0.078231       NaN       NaN       NaN
# 94043       0.020415 -0.059937       NaN       NaN       NaN
# 94044       0.019805 -0.073826       NaN       NaN       NaN
# 94045       0.021787  0.090580       NaN       NaN       NaN
# 94046       0.018647 -0.189369       NaN       NaN       NaN
# 94047       0.021578  0.040984       NaN       NaN       NaN
# 94048       0.022214  0.062992       NaN       NaN       NaN
# 94049       0.021201 -0.129630       NaN       NaN       NaN
# 94050       0.024748  0.182979       NaN       NaN       NaN
# 94051       0.019597  0.269784 -0.181035       NaN       NaN
# 94052       0.020182 -0.033994  0.056140       NaN       NaN
# 94053       0.020494 -0.196481 -0.023256       NaN       NaN
# 94054       0.020626 -0.040146  0.078231       NaN       NaN
# 94055       0.022787  0.072243 -0.059937       NaN       NaN
# 94056       0.023232  0.007092 -0.073826       NaN       NaN
# 94057       0.020503 -0.172535  0.090580       NaN       NaN
# 94058       0.022252  0.025532 -0.189369       NaN       NaN
# 94059       0.018386 -0.186722  0.040984       NaN       NaN
# 94060       0.015270 -0.137755  0.062992       NaN       NaN
# 94061       0.015668 -0.026509 -0.129630       NaN       NaN
# 94062       0.011389  0.264284  0.182979       NaN       NaN
# 94063       0.005815 -0.221154  0.269784 -0.181035       NaN
# 94064       0.007333  0.030864 -0.033994  0.056140       NaN
# 94065       0.013847  0.137725 -0.196481 -0.023256       NaN
# 94066       0.014205  0.026316 -0.040146  0.078231       NaN
# 94067       0.013306  0.164103  0.072243 -0.059937       NaN
# 94068       0.013329  0.066079  0.007092 -0.073826       NaN
# 94069       0.013344  0.053719 -0.172535  0.090580       NaN
# 94070       0.018949  0.160784  0.025532 -0.189369       NaN
# 94071       0.018483 -0.043919 -0.186722  0.040984       NaN
# 94072       0.019041  0.060071 -0.137755  0.062992       NaN
# 94073       0.019827 -0.050000 -0.026509 -0.129630       NaN
# 94074       0.019757  0.070175  0.264284  0.182979       NaN
# 94075       0.019031 -0.052459 -0.221154  0.269784 -0.181035
# 94076       0.018084 -0.083045  0.030864 -0.033994  0.056140
# 94077       0.010081  0.332075  0.137725 -0.196481 -0.023256
# 94078       0.008789  0.135977  0.026316 -0.040146  0.078231
# 94079       0.010871  0.074813  0.164103  0.072243 -0.059937
# 94080       0.010628  0.041763  0.066079  0.007092 -0.073826
# 94081       0.010219  0.044543  0.053719 -0.172535  0.090580
# 94082       0.010228 -0.234542  0.160784  0.025532 -0.189369
# 94083       0.010623  0.033426 -0.043919 -0.186722  0.040984
# 94084       0.010074 -0.059299  0.060071 -0.137755  0.062992
# 94085       0.008491  0.151862 -0.050000 -0.026509 -0.129630

# %%
# get year = 2013
_test = df[(df["NCUSIP"] == "U7260311") & (df["date"].dt.year == 2016)]

mult = 1
for _t in _test['RET']:
    mult = mult * (1 + _t)
mult - 1
# Out:
# 0.3377013626824048

# %%
df["ME"] = abs(df["PRC"]) * df["SHROUT"]

# %%
df.drop(columns=["VOL", "vwretd"], inplace=True, errors="ignore")
df.sort_values(by=["date", "NCUSIP"], inplace=True)
df
# Out:
#            date    NCUSIP TICKER                        COMNAM      PRC  \
# 534646  2002-01  00036020   AAON                      AAON INC  19.6995
# 416442  2002-01  00036110    AIR                    A A R CORP   8.6000
# 637054  2002-01  00040010   ABCB                 A B C BANCORP  13.5000
# 836648  2002-01  00078810   ABWG          A B WATLEY GROUP INC   1.4400
# 776558  2002-01  00086T10   ACMR  AC MOORE ARTS AND CRAFTS INC  27.3800
# ...         ...       ...    ...                           ...      ...
# 188697  2024-12  98985Y10   ZYME              ZYMEWORKS INC DE  14.6400
# 223468  2024-12  98986M10   ZYXI                     ZYNEX INC   8.0100
# 295066  2024-12  98987D30   ZVSA      ZYVERSA THERAPEUTICS INC   1.0600
# 251591  2024-12  G6516310   JOBY             JOBY AVIATION INC   8.1300
# 317701  2024-12  G8292E10    SKK              SKK HOLDINGS LTD   0.9900
#
#              RET    SHROUT    sprtrn  NasdaqDummy  past_return  \
# 534646 -0.194953    8666.0 -0.015574            1          NaN
# 416442 -0.042730   26859.0 -0.015574            0          NaN
# 637054  0.011236    9999.0 -0.015574            1          NaN
# 836648 -0.389830   12887.0 -0.015574            1          NaN
# 776558 -0.071864    7466.0 -0.015574            1          NaN
# ...          ...       ...       ...          ...          ...
# 188697  0.039035   69163.0 -0.024990            1     0.409047
# 223468 -0.037260   31846.0 -0.024990            1    -0.264463
# 295066 -0.012944    2344.0 -0.024990            1          NaN
# 251591 -0.091620  765086.0 -0.024990            0     0.222556
# 317701 -0.297872   15625.0 -0.024990            1          NaN
#
#         past_return_skip  past_variance        R1        R2        R3  \
# 534646               NaN            NaN       NaN       NaN       NaN
# 416442               NaN            NaN       NaN       NaN       NaN
# 637054               NaN            NaN       NaN       NaN       NaN
# 836648               NaN            NaN       NaN       NaN       NaN
# 776558               NaN            NaN       NaN       NaN       NaN
# ...                  ...            ...       ...       ...       ...
# 188697          0.356111       0.011967  0.171364  0.018135       NaN
# 223468         -0.235996       0.007309  0.188865  0.013848 -0.221094
# 295066               NaN            NaN       NaN       NaN       NaN
# 251591          0.345864       0.075974  0.115772 -0.186893 -0.079445
# 317701               NaN            NaN       NaN       NaN       NaN
#
#               R4           ME
# 534646       NaN   170715.867
# 416442       NaN   230987.400
# 637054       NaN   134986.500
# 836648       NaN    18557.280
# 776558       NaN   204419.080
# ...          ...          ...
# 188697       NaN  1012546.320
# 223468 -0.035817   255086.460
# 295066       NaN     2484.640
# 251591       NaN  6220149.180
# 317701       NaN    15468.750
#
# [1144940 rows x 17 columns]

# %%
# save to csv
df.to_csv('..\\baseline_data\\stock_price_monthly_2003_2024.csv', index=False)
